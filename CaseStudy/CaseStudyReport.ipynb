# %% [markdown]
# # Case Study- Big Data
# - By : Siny P Raphel
# - Github: https://github.com/sinypr/Data-Engineering-Training/tree/main/CaseStudy

# %% [markdown]
# ## Question 1 - Voter List:

# %% [markdown]
# First in mysql database I created a database 76074_Source and then created a table voters as shown below.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Created directories in hdfs using the mkdir command
#
# ![image.png](attachment:image.png)
#
# Resulting in the following folders in hdfs
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# Created a hive database and table
#
# ![image-3.png](attachment:image-3.png)
#
# ![image-4.png](attachment:image-4.png)
#
# ![image-5.png](attachment:image-5.png)
#
# ![image-6.png](attachment:image-6.png)

# %% [markdown]
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### Question 1
#
# Extract the person details who is eligible (>= 18 years old) to vote as on
# 15/09/2019.

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# Snapshot of the result when it is ordered by dateofbirth
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Question 2
#
# Find out the persons going to vote next year as on 15/09/2020

# %% [markdown]
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### Question 3
#
# Find the count of gender in each city.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Question 2: Gender Analysis

# %% [markdown]
# In the original data the years were columns as shown below
#
# ![image.png](attachment:image.png)
#
# I used pyspark script to convert this columns into rows using the stack() of spark. The code can be found in the github link https://github.com/sinypr/Data-Engineering-Training/blob/d18e7a84822b42e242ce6f8bca8d3c2171eb78b3/CaseStudy/Q2_data_preprocessing.ipynb
#
# and the result is as below.
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# The result is then stored in csv file which is loaded to local hadoop system using winscp.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# A table is created in hive using the below scripts

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# In the above code serde escape characters are used to escape the commas inside the quotes and so that the values are correctly read to the corresponding columns. The result is displayed below.

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# The command loads data from local hadoop to hive table previously created.

# %% [markdown]
# ### Question 1:
# - Identify the countries where % of female graduates is less than 30%

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Question 2:
# List the average increase in female education in the U.S. from the year 2000.

# %% [markdown]
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# In USA the percentage of female education is gradually increasing in an average of less than .25%

# %% [markdown]
# ### Question 3:
# - List the % of change in male employment from the year 2000.

# %% [markdown]
# ![image.png](attachment:image.png)
#
# The above query displays indicator names that contains employment to population ratio.
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image-2.png](attachment:image-2.png)
#
# ![image.png](attachment:image.png)
#
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ### Question 4:
# - List the % of change in female employment from the year 2000.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# At  GLANCE, in developed countries like USA both female and male employment percentages are close and more than 50%. Where as in a developing country like India, there is a huge difference between the male and female employment percentage.  But this analysis can not be generalised. More factors like population should be considered in the analysis.

# %% [markdown]
# ## Question 3: Analyze data set from Stack Exchange

# %% [markdown]
# The analysis is done in pyspark which can be found in my github link below:
# * https://github.com/sinypr/Data-Engineering-Training/tree/main/CaseStudy/CaseStudy_Q3.ipynb
